# %% [markdown]
# # Synthetic Data Generation

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import matplotlib.pyplot as plt

from src import Flag, AbstractTask, AbstractFlag, Pipeline
import numpy as np

from matplotlib.ticker import PercentFormatter
from src import PlotPipelineFactory
import warnings
warnings.filterwarnings("ignore")

# %%
dataPath = r"..\data\csv" + "\\"
picklePath = r"..\pickle_objects\modeling_pipeline" + "\\"
plotPath = r"..\plots\inference V3" + "\\"
modelPath = r"..\pickle_objects\models_and_scalers" + "\\"

# %%
import pickle
with open(picklePath + 'Modeling Pipeline.pickle', 'rb') as f:
    ModelingPipeline = pickle.load(f)

ModelingPipeline.print(priority = True, flags = True)
# Out:
# Modeling Pipeline
# 	10 Pre Processing: Pre Processing
# 		10 Select and order columns
# 		20 Company ID and UUID
# 			10 Fill Company ID with None
# 			20 Fill UUID with None
# 			30 Replace Company IDs
# 			40 Replace Company UUIDs
# 		30 MS Data Processing
# 			10 Fill MS Data with empty String
# 			20 Length of MS Data
# 			30 Continuity Type
# 			40 Drop MS Data Column
# 		40 Service Data Processing
# 			10 Fill Service Data with empty String
# 			20 Length of Service Data
# 			30 Samsung Type
# 			40 Drop Service Data Column
# 		50 Fill Numeric NA with 0
# 		60 Fill String NA with None
# 		70 Datetime conversion
# 		80 Clean PDU
# 		90 Order DataFrame
# 		100 Convert object type to string
# 	20 Dummy Processing: Dummy Processing
# 		10 Dummies Channel
# 		20 Dummies AD Type
# 		30 Dummies Company
# 		40 Dummies UUID
# 		50 Dummies PDU Type
# 		60 Dummies Continuity Type
# 		70 Dummies SmartTag Type
# 	30 Labeling: Labeling
# 		10 Labeling auto: Labeling auto
# 			Label FindMy Tracker and iDevice: Label FindMy Tracker and iDevice
# 			Label Tile and iDevice: Label Tile and iDevice
# 			Label AirPod and iDevice: Label AirPod and iDevice
# 			Label other Device and SmartTag: Label SmartTag and Other
# 		20 Labeling manual: Labeling manual
# 			Label FindMy Tracker: Label FindMy Tracker
# 			Label iDevice: Label iDevice
# 			Label SmartTag: Label SmartTag
# 			Label Tile: Label Tile
# 			Label other Device: Label other Device
# 			Label AirPod: Label AirPod
# 			Label -1: Label Unknown
# 	40 States: States
# 		10 State Column
# 		20 States iDevices: States iDevices
# 			Continuity
# 		30 States Trackers: States Tracker
# 			lost: State lost
# 			nearby: State nearby
# 			unpaired: State unpaired
# 		Collapse State Column
# 	50 Drop Labels: Drop Labels
# 		Drop iDevice: Drop iDevice
# 		Drop other Device: Drop other Device
# 		Drop iDevice FindMy: Drop iDevice FindMy
# 	60 Modeling: Modeling
# 		0 Drop Column Continuity
# 		10 Rate Modeling: Rate Modeling
# 		20 Drop Columns: Drop Columns

# %%
with open(picklePath + 'Pre Processing.pickle', 'rb') as f:
    flag_preProcessing = pickle.load(f)

with open(picklePath +  'Modeling.pickle', 'rb') as f:
    flag_modeling = pickle.load(f)

with open(picklePath + 'Dummy Processing.pickle', 'rb') as f:
    flag_dummy= pickle.load(f)

with open(picklePath + 'Rate Modeling.pickle', 'rb') as f:
    flag_Rate_Modeling = pickle.load(f)

# %%
def filesToDataFrame(filesDict: dict[str:AbstractFlag], filePath:str = dataPath, config:AbstractTask = ModelingPipeline) -> pd.DataFrame:
    dataset = pd.DataFrame()

    for f in filesDict.keys():
        new_dataset = Pipeline().setPath(filePath + f).setTask(config).loadData().run(flag=filesDict[f])
        dataset = pd.concat([dataset, new_dataset])
        
    dataset.reset_index(drop = True, inplace = True)

    return dataset

def Inference(dataset: pd.DataFrame, modelName: str, scalerName: str, path:str = modelPath):
    with open(path + modelName + ".pickle", 'rb') as f:
        model = pickle.load(f)

    with (open(path + scalerName + ".pickle", 'rb') as f):
        scaler = pickle.load(f)
        
    sourceData = dataset[['Source','Time']]
    dataset = dataset.drop(columns=['Source','Time'], axis = 1)

    X_scaled = scaler.transform(dataset.copy(deep=True).to_numpy())
    
    y_pred = model.predict_proba(X_scaled)
    y_pred = pd.DataFrame(data=y_pred, columns=model.classes_)
    
    y_pred = y_pred.round(4) * 100
    y_pred = pd.concat([sourceData, y_pred], axis=1)
    y_pred['Label'] = model.predict(X_scaled)
    y_pred['Label'] = y_pred['Label'].astype("string")

    y_pred['Max Proba'] = y_pred.iloc[:, 2:-1].max(axis = 1)
    
    return y_pred, list(model.classes_)

# %%
Modeling_Flag = Flag("Modeling", parents=[flag_modeling, flag_dummy, flag_preProcessing])

files = {"Inference\Bahnhof_V1.csv": Modeling_Flag,
         }

data = filesToDataFrame(files)

y_pred, labels = Inference(data, modelName = "Neural Network model", scalerName="Neural Network scaler")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97990 entries, 0 to 97989
# Data columns (total 31 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Time                                        97990 non-null  datetime64[ns]
#  1   Source                                      97990 non-null  string
#  2   Length Packet                               97990 non-null  int64
#  3   Length Header                               97990 non-null  int64
#  4   Length MS Data                              97990 non-null  int32
#  5   Length Service Data                         97990 non-null  int32
#  6   CH 37                                       97990 non-null  int32
#  7   CH 38                                       97990 non-null  int32
#  8   CH 39                                       97990 non-null  int32
#  9   AD Manufacturer Specific                    97990 non-null  int32
#  10  AD Flags                                    97990 non-null  int32
#  11  AD Tx Power Level                           97990 non-null  int32
#  12  AD Service Data - 16 bit UUID               97990 non-null  int32
#  13  AD 16-bit Service Class UUIDs               97990 non-null  int32
#  14  AD 16-bit Service Class UUIDs (incomplete)  97990 non-null  int32
#  15  AD Other                                    97990 non-null  int32
#  16  COMP Apple                                  97990 non-null  int32
#  17  COMP Other                                  97990 non-null  int32
#  18  UUID Samsung                                97990 non-null  int32
#  19  UUID Tile                                   97990 non-null  int32
#  20  UUID Other                                  97990 non-null  int32
#  21  PDU ADV_IND                                 97990 non-null  int32
#  22  PDU ADV_NONCONN_IND                         97990 non-null  int32
#  23  PDU ADV_SCAN_IND                            97990 non-null  int32
#  24  PDU Other                                   97990 non-null  int32
#  25  CT 07                                       97990 non-null  int32
#  26  CT 12                                       97990 non-null  int32
#  27  CT Other                                    97990 non-null  int32
#  28  ST 3                                        97990 non-null  int64
#  29  ST 5                                        97990 non-null  int32
#  30  ST Other                                    97990 non-null  int32
# dtypes: datetime64[ns](1), int32(26), int64(3), string(1)
# memory usage: 13.5 MB

# %%
y_pred.head()
# Out:
#               Source                          Time  FindMy Tracker (lost)  \
# 0  72:bd:26:15:e5:43 2024-04-25 15:04:30.115560055                    0.0
# 1  58:6e:60:f8:8b:b2 2024-04-25 15:04:30.115560055                    0.0
# 2  58:6e:60:f8:8b:b2 2024-04-25 15:04:30.117041111                    0.0
# 3  58:6e:60:f8:8b:b2 2024-04-25 15:04:30.118024111                    0.0
# 4  57:77:6e:a6:b3:df 2024-04-25 15:04:30.119189978                    0.0
#
#    FindMy Tracker (nearby)  FindMy Tracker (unpaired)  SmartTag (lost)  \
# 0                     0.00                       0.00              0.0
# 1                     0.00                       0.00              0.0
# 2                     0.00                       0.00              0.0
# 3                     0.00                       0.00              0.0
# 4                     0.03                       0.02              0.0
#
#    SmartTag (nearby)  Tile (lost)  iDevice  iDevice FindMy offline  \
# 0                0.0         0.00   100.00                    0.00
# 1                0.0         0.00   100.00                    0.00
# 2                0.0         0.00   100.00                    0.00
# 3                0.0         0.00   100.00                    0.00
# 4               37.0         0.02     0.05                    0.01
#
#    iDevice FindMy online  other Device         Label  Max Proba
# 0                   0.00          0.00       iDevice     100.00
# 1                   0.00          0.00       iDevice     100.00
# 2                   0.00          0.00       iDevice     100.00
# 3                   0.00          0.00       iDevice     100.00
# 4                   0.01         62.86  other Device      62.86

# %%
def plotLorenz(dataToPlot):
    title_suffix = str(dataToPlot['Label'].iloc[0])
    title = 'Confidence - ' + title_suffix

    dataToPlot = dataToPlot.sort_values(by = 'Max Proba', ascending = False)
    dataToPlot['Percentile'] = np.arange(0, dataToPlot.shape[0]) / (dataToPlot.shape[0] - 1)

    plt.figure(figsize = (16, 9), dpi = 100)
    plt.plot(dataToPlot['Percentile'], dataToPlot['Max Proba'] / 100)
    plt.xlim(0)
    plt.ylim(bottom = 0, top = 1.1)
    plt.title(title, fontsize = 20)
    plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
    plt.gca().xaxis.set_major_formatter(PercentFormatter(1))
  
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.ylabel("Confidence", fontsize = 15)
    plt.xlabel("% of Packets", fontsize = 15)
    plt.tight_layout()
    plt.savefig(plotPath + "confidence" + "\\" + title + '.png', dpi = 300)
    plt.show()

# %%
y_pred.groupby('Label').apply(plotLorenz)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
y_pred
# Out:
#                   Source                          Time  FindMy Tracker (lost)  \
# 0      72:bd:26:15:e5:43 2024-04-25 15:04:30.115560055                    0.0
# 1      58:6e:60:f8:8b:b2 2024-04-25 15:04:30.115560055                    0.0
# 2      58:6e:60:f8:8b:b2 2024-04-25 15:04:30.117041111                    0.0
# 3      58:6e:60:f8:8b:b2 2024-04-25 15:04:30.118024111                    0.0
# 4      57:77:6e:a6:b3:df 2024-04-25 15:04:30.119189978                    0.0
# ...                  ...                           ...                    ...
# 97985  78:a6:72:61:ca:f8 2024-04-25 15:14:32.456671953                    0.0
# 97986  4c:43:00:86:e9:cb 2024-04-25 15:14:32.480820894                    0.0
# 97987  6a:ee:d9:d3:35:62 2024-04-25 15:14:32.494939089                    0.0
# 97988  42:39:98:6f:b4:6f 2024-04-25 15:14:32.498136044                    0.0
# 97989  57:b2:11:46:d8:44 2024-04-25 15:14:32.531002045                    0.0
#
#        FindMy Tracker (nearby)  FindMy Tracker (unpaired)  SmartTag (lost)  \
# 0                         0.00                       0.00             0.00
# 1                         0.00                       0.00             0.00
# 2                         0.00                       0.00             0.00
# 3                         0.00                       0.00             0.00
# 4                         0.03                       0.02             0.00
# ...                        ...                        ...              ...
# 97985                     0.03                       0.02             0.00
# 97986                     0.01                       0.00             0.01
# 97987                     0.00                       0.00             0.00
# 97988                     0.00                       0.00             0.00
# 97989                     0.00                       0.00             0.00
#
#        SmartTag (nearby)  Tile (lost)  iDevice  iDevice FindMy offline  \
# 0                   0.00         0.00   100.00                    0.00
# 1                   0.00         0.00   100.00                    0.00
# 2                   0.00         0.00   100.00                    0.00
# 3                   0.00         0.00   100.00                    0.00
# 4                  37.00         0.02     0.05                    0.01
# ...                  ...          ...      ...                     ...
# 97985              37.00         0.02     0.05                    0.01
# 97986               0.01         0.01     0.03                    0.00
# 97987               0.00         0.00   100.00                    0.00
# 97988               0.00         0.00   100.00                    0.00
# 97989               0.00         0.00    99.99                    0.00
#
#        iDevice FindMy online  other Device         Label  Max Proba
# 0                       0.00          0.00       iDevice     100.00
# 1                       0.00          0.00       iDevice     100.00
# 2                       0.00          0.00       iDevice     100.00
# 3                       0.00          0.00       iDevice     100.00
# 4                       0.01         62.86  other Device      62.86
# ...                      ...           ...           ...        ...
# 97985                   0.01         62.86  other Device      62.86
# 97986                   0.00         99.93  other Device      99.93
# 97987                   0.00          0.00       iDevice     100.00
# 97988                   0.00          0.00       iDevice     100.00
# 97989                   0.00          0.00       iDevice      99.99
#
# [97990 rows x 14 columns]

# %%
temp = y_pred.copy(deep = True)

# %%
temp = temp.groupby(['Source', 'Label']).agg(Count = ('Label', 'count'), Probability = ('Max Proba', 'mean')).reset_index()

temp['Score'] = temp['Count'] * temp['Probability']
temp['Score'] = 100 *  temp['Score'] / temp.groupby(['Source'])['Score'].transform('sum')
temp = temp.round(2)
temp
# Out:
#                  Source                   Label  Count  Probability   Score
# 0     00:09:a7:5a:93:16            other Device      7       100.00  100.00
# 1     00:1b:66:c0:1d:42             Tile (lost)      5        56.62   30.37
# 2     00:1b:66:c0:1d:42            other Device     10        64.91   69.63
# 3     01:02:00:4b:d3:17            other Device      1        99.16  100.00
# 4     01:02:48:42:2b:e5            other Device      1        99.98  100.00
# ...                 ...                     ...    ...          ...     ...
# 5243  ff:8a:80:f9:ce:91            other Device      1       100.00  100.00
# 5244  ff:a5:6c:ba:8a:31   iDevice FindMy online     10        99.99  100.00
# 5245  ff:d4:21:80:72:3f   iDevice FindMy online      2        99.99  100.00
# 5246  ff:d7:3f:79:d3:62  iDevice FindMy offline      1        99.99  100.00
# 5247  ff:f8:24:84:86:f6  iDevice FindMy offline      6        99.99  100.00
#
# [5248 rows x 5 columns]

# %%
devices = temp.loc[temp.groupby(['Source'])['Score'].idxmax()]
devices
# Out:
#                  Source                   Label  Count  Probability   Score
# 0     00:09:a7:5a:93:16            other Device      7       100.00  100.00
# 2     00:1b:66:c0:1d:42            other Device     10        64.91   69.63
# 3     01:02:00:4b:d3:17            other Device      1        99.16  100.00
# 4     01:02:48:42:2b:e5            other Device      1        99.98  100.00
# 5     01:02:4b:ea:71:34            other Device      1        99.56  100.00
# ...                 ...                     ...    ...          ...     ...
# 5243  ff:8a:80:f9:ce:91            other Device      1       100.00  100.00
# 5244  ff:a5:6c:ba:8a:31   iDevice FindMy online     10        99.99  100.00
# 5245  ff:d4:21:80:72:3f   iDevice FindMy online      2        99.99  100.00
# 5246  ff:d7:3f:79:d3:62  iDevice FindMy offline      1        99.99  100.00
# 5247  ff:f8:24:84:86:f6  iDevice FindMy offline      6        99.99  100.00
#
# [4550 rows x 5 columns]

# %%
threshold = 0
devices = devices[devices['Probability'] > threshold]

# %%
deviceCounts = devices.groupby('Label').size().reset_index().rename(columns = {0:'Count'})

x = deviceCounts['Label']
y = deviceCounts['Count']

title = "Device Count - Inference"
plt.figure(figsize=(16, 10), dpi = 100),
plt.bar(x, y)

offset = y.max() * 0.01
for i in range(len(x)):
    plt.text(i, y[i] + offset, np.round(y[i]), ha='center', fontsize = 12)
        
plt.ylabel("Number of Devices", fontsize=15)
plt.xticks(rotation = 90, fontsize=15)
plt.yticks(fontsize=15)
plt.title(title, fontsize = 20)
plt.tight_layout()
plt.savefig(plotPath + title + '.png', dpi = 300)
plt.show()

# %%
print(round(devices['Source'].nunique() * 100 / y_pred['Source'].nunique(),1),"%")
# Out:
# 100.0 %

# %%
print(round(len(y_pred.merge(devices, on = ['Source'], how = 'inner')) / len(y_pred) * 100,1), '%')
# Out:
# 100.0 %

# %%
InferencePipeline = ModelingPipeline[0]
InferencePipeline.print(priority = True, flags = True)
# Out:
# 10 Pre Processing: Pre Processing
# 	10 Select and order columns
# 	20 Company ID and UUID
# 		10 Fill Company ID with None
# 		20 Fill UUID with None
# 		30 Replace Company IDs
# 		40 Replace Company UUIDs
# 	30 MS Data Processing
# 		10 Fill MS Data with empty String
# 		20 Length of MS Data
# 		30 Continuity Type
# 		40 Drop MS Data Column
# 	40 Service Data Processing
# 		10 Fill Service Data with empty String
# 		20 Length of Service Data
# 		30 Samsung Type
# 		40 Drop Service Data Column
# 	50 Fill Numeric NA with 0
# 	60 Fill String NA with None
# 	70 Datetime conversion
# 	80 Clean PDU
# 	90 Order DataFrame
# 	100 Convert object type to string

# %%
def getPlotPipeline(titleSuffix: str, labelColumn: str = 'Label', show: bool = False, savePath: str = plotPath, mode:str='inference'):
    return PlotPipelineFactory(titleSuffix=titleSuffix, labelColumn=labelColumn, show=show, savePath=savePath, mode = mode)

def filesToPlottingDataFrame(filesList: list[str], filePath: str = dataPath, dropLabels:list[str]=None, deviceTable = devices, labelColumn = 'Label', 
                             config: AbstractTask = InferencePipeline) -> pd.DataFrame:
    if dropLabels is None:
        dropLabels = []
    dataset = pd.DataFrame()

    for index, f in enumerate(filesList):
        myPipeline = Pipeline().setPath(filePath + f).loadData()

        new_dataset = myPipeline.setTask(config).run()
        new_dataset['File'] = 'File ' + str(index+1)
        
        dataset = pd.concat([dataset, new_dataset])
    
    dataset = dataset.merge(deviceTable, on = ['Source'], how = 'inner')
    
    for label in dropLabels:
            dataset = dataset[~dataset[labelColumn].str.contains(label)]

    dataset = dataset[~dataset[labelColumn].isin(dropLabels)]

    dataset.reset_index(drop = True, inplace = True)

    return dataset

# %%
files = ["Inference\Bahnhof_V1.csv",
         ]

data = filesToPlottingDataFrame(files)

plotPipeline = getPlotPipeline('Synthetic Data Generation')
data = plotPipeline.execute(data)

# %%
devices
# Out:
#                  Source                   Label  Count  Probability   Score
# 0     00:09:a7:5a:93:16            other Device      7       100.00  100.00
# 2     00:1b:66:c0:1d:42            other Device     10        64.91   69.63
# 3     01:02:00:4b:d3:17            other Device      1        99.16  100.00
# 4     01:02:48:42:2b:e5            other Device      1        99.98  100.00
# 5     01:02:4b:ea:71:34            other Device      1        99.56  100.00
# ...                 ...                     ...    ...          ...     ...
# 5243  ff:8a:80:f9:ce:91            other Device      1       100.00  100.00
# 5244  ff:a5:6c:ba:8a:31   iDevice FindMy online     10        99.99  100.00
# 5245  ff:d4:21:80:72:3f   iDevice FindMy online      2        99.99  100.00
# 5246  ff:d7:3f:79:d3:62  iDevice FindMy offline      1        99.99  100.00
# 5247  ff:f8:24:84:86:f6  iDevice FindMy offline      6        99.99  100.00
#
# [4550 rows x 5 columns]

# %%
tracker = 'SmartTag (nearby)'
sources = y_pred[y_pred['Label'] == tracker]
sources['Source'].unique()
sources.reset_index(inplace=True, drop=True)
sources = sources.drop_duplicates()
sources
# Out:
#                 Source                          Time  FindMy Tracker (lost)  \
# 0    4c:d6:22:22:c9:d1 2024-04-25 15:04:30.166889906                   0.03
# 1    4c:d6:22:22:c9:d1 2024-04-25 15:04:30.222747087                   0.03
# 2                 None 2024-04-25 15:04:30.298043966                   0.00
# 3    6f:a9:fa:78:63:36 2024-04-25 15:04:30.316032887                   0.05
# 4    4c:d6:22:22:c9:d1 2024-04-25 15:04:30.605292082                   0.03
# ..                 ...                           ...                    ...
# 386  a0:9e:1a:b3:e6:8b 2024-04-25 15:14:20.858103037                   0.01
# 387  58:0e:73:0d:2b:79 2024-04-25 15:14:24.664510012                   0.05
# 388  68:37:3b:16:ce:3e 2024-04-25 15:14:26.377909899                   0.04
# 389  6a:e6:d9:d3:35:62 2024-04-25 15:14:26.987545967                   0.00
# 390  55:ad:ae:95:71:1a 2024-04-25 15:14:27.186383009                   0.05
#
#      FindMy Tracker (nearby)  FindMy Tracker (unpaired)  SmartTag (lost)  \
# 0                       4.44                       0.52             0.03
# 1                       4.44                       0.52             0.03
# 2                       0.05                       0.02             0.00
# 3                       7.36                       0.46             0.05
# 4                       4.44                       0.52             0.03
# ..                       ...                        ...              ...
# 386                     2.80                       0.55             0.01
# 387                     2.08                       0.73             0.03
# 388                     0.34                       0.66             0.05
# 389                     0.29                       0.15             0.03
# 390                     2.30                       0.70             0.03
#
#      SmartTag (nearby)  Tile (lost)  iDevice  iDevice FindMy offline  \
# 0                91.00         0.16     0.15                    0.00
# 1                91.00         0.16     0.15                    0.00
# 2                50.86         0.02     0.06                    0.01
# 3                87.50         0.36     0.15                    0.00
# 4                91.00         0.16     0.15                    0.00
# ..                 ...          ...      ...                     ...
# 386              52.00         0.00     0.32                    0.00
# 387              88.58         0.19     0.20                    0.00
# 388              56.69         0.72    34.44                    0.00
# 389              80.21         0.00     0.01                    0.00
# 390              89.16         0.19     0.19                    0.00
#
#      iDevice FindMy online  other Device              Label  Max Proba
# 0                     0.00          3.68  SmartTag (nearby)      91.00
# 1                     0.00          3.68  SmartTag (nearby)      91.00
# 2                     0.03         48.94  SmartTag (nearby)      50.86
# 3                     0.00          4.07  SmartTag (nearby)      87.50
# 4                     0.00          3.68  SmartTag (nearby)      91.00
# ..                     ...           ...                ...        ...
# 386                   0.00         44.31  SmartTag (nearby)      52.00
# 387                   0.00          8.14  SmartTag (nearby)      88.58
# 388                   0.00          7.07  SmartTag (nearby)      56.69
# 389                   0.00         19.31  SmartTag (nearby)      80.21
# 390                   0.00          7.39  SmartTag (nearby)      89.16
#
# [391 rows x 14 columns]

# %%
sources = devices[devices['Label'] == tracker][['Source']]
original_data = pd.read_csv(dataPath + r"Inference\Bahnhof_V1.csv", encoding='cp1252')

# %%
original_data
# Out:
#        Number  Time Delta          Time             Source        Destination  \
# 0           1    0.000000  1.714057e+09  72:bd:26:15:e5:43  ff:ff:ff:ff:ff:ff
# 1           2    0.000000  1.714057e+09  58:6e:60:f8:8b:b2  ff:ff:ff:ff:ff:ff
# 2           3    0.001481  1.714057e+09  58:6e:60:f8:8b:b2  ff:ff:ff:ff:ff:ff
# 3           4    0.002464  1.714057e+09  58:6e:60:f8:8b:b2  ff:ff:ff:ff:ff:ff
# 4           5    0.003630  1.714057e+09  57:77:6e:a6:b3:df  58:6e:60:f8:8b:b2
# ...       ...         ...           ...                ...                ...
# 97985   97986  602.341112  1.714058e+09  78:a6:72:61:ca:f8  78:20:ee:cb:d8:29
# 97986   97987  602.365261  1.714058e+09  4c:43:00:86:e9:cb  ff:ff:ff:ff:ff:ff
# 97987   97988  602.379379  1.714058e+09  6a:ee:d9:d3:35:62  ff:ff:ff:ff:ff:ff
# 97988   97989  602.382576  1.714058e+09  42:39:98:6f:b4:6f  ff:ff:ff:ff:ff:ff
# 97989   97990  602.415442  1.714058e+09  57:b2:11:46:d8:44  ff:ff:ff:ff:ff:ff
#
#       Protocol  Channel  Length Packet  Length Header  \
# 0        LE LL       37             49             23
# 1        LE LL       38             49             23
# 2        LE LL       39             49             23
# 3        LE LL       37             49             23
# 4        LE LL       37             38             12
# ...        ...      ...            ...            ...
# 97985    LE LL       37             38             12
# 97986    LE LL       39             50             24
# 97987    LE LL       39             51             25
# 97988    LE LL       38             46             20
# 97989    LE LL       39             49             23
#
#                                                  AD Type   Company ID  \
# 0             Flags,Tx Power Level,Manufacturer Specific  Apple, Inc.
# 1             Flags,Tx Power Level,Manufacturer Specific  Apple, Inc.
# 2             Flags,Tx Power Level,Manufacturer Specific  Apple, Inc.
# 3             Flags,Tx Power Level,Manufacturer Specific  Apple, Inc.
# 4                                                    NaN          NaN
# ...                                                  ...          ...
# 97985                                                NaN          NaN
# 97986  Tx Power Level,Service Data - 16 bit UUID,16-b...          NaN
# 97987         Flags,Tx Power Level,Manufacturer Specific  Apple, Inc.
# 97988         Flags,Tx Power Level,Manufacturer Specific  Apple, Inc.
# 97989                        Flags,Manufacturer Specific  Apple, Inc.
#
#                     MS Data                     UUID    Service Data  \
# 0            100506184015bf                      NaN             NaN
# 1            10052d18f2fd9b                      NaN             NaN
# 2            10052d18f2fd9b                      NaN             NaN
# 3            10052d18f2fd9b                      NaN             NaN
# 4                       NaN                      NaN             NaN
# ...                     ...                      ...             ...
# 97985                   NaN                      NaN             NaN
# 97986                   NaN  Google,Sony Corporation  00300000001145
# 97987    1007341f1319db6f18                      NaN             NaN
# 97988              10022100                      NaN             NaN
# 97989  160800ca70213ff8dcf6                      NaN             NaN
#
#                    PDU
# 0              ADV_IND
# 1              ADV_IND
# 2              ADV_IND
# 3              ADV_IND
# 4             SCAN_REQ
# ...                ...
# 97985         SCAN_REQ
# 97986          ADV_IND
# 97987          ADV_IND
# 97988          ADV_IND
# 97989  ADV_NONCONN_IND
#
# [97990 rows x 15 columns]

# %%
SmartTagData = original_data.merge(sources, on = ['Source'], how = 'inner')
SmartTagData = SmartTagData.sort_values(by = 'UUID', ascending = True)
SmartTagData = SmartTagData.reset_index(drop = True)
SmartTagData = SmartTagData[~SmartTagData['UUID'].str.contains('Samsung', na=False)]

# %%
SmartTagData
# Out:
#      Number  Time Delta          Time             Source        Destination  \
# 0     97366  596.871986  1.714058e+09  6a:e6:d9:d3:35:62  ff:ff:ff:ff:ff:ff
# 2     66641  399.452170  1.714058e+09  80:c3:ba:47:3a:8b  ff:ff:ff:ff:ff:ff
# 3     63562  378.549317  1.714058e+09  80:c3:ba:47:3a:8b  ff:ff:ff:ff:ff:ff
# 4     63558  378.547473  1.714058e+09  80:c3:ba:47:3a:8b  ff:ff:ff:ff:ff:ff
# 5     63501  378.134599  1.714058e+09  80:c3:ba:47:3a:8b  ff:ff:ff:ff:ff:ff
# ..      ...         ...           ...                ...                ...
# 504   89876  557.661649  1.714058e+09  69:90:8a:71:39:74  ff:ff:ff:ff:ff:ff
# 505   91852  565.268196  1.714058e+09  5c:ab:cc:6d:50:fb  ff:ff:ff:ff:ff:ff
# 506   97105  594.548950  1.714058e+09  58:0e:73:0d:2b:79  ff:ff:ff:ff:ff:ff
# 507   97301  596.262350  1.714058e+09  68:37:3b:16:ce:3e  ff:ff:ff:ff:ff:ff
# 508   97377  597.070823  1.714058e+09  55:ad:ae:95:71:1a  ff:ff:ff:ff:ff:ff
#
#     Protocol  Channel  Length Packet  Length Header  \
# 0      LE LL       37             51             25
# 2      LE LL       39             49             23
# 3      LE LL       39             49             23
# 4      LE LL       37             49             23
# 5      LE LL       39             49             23
# ..       ...      ...            ...            ...
# 504    LE LL       39             34              8
# 505    LE LL       37             51             25
# 506    LE LL       37             51             25
# 507    LE LL       37             51             25
# 508    LE LL       37             49             23
#
#                                                AD Type Company ID MS Data  \
# 0    Flags,16-bit Service Class UUIDs (incomplete),...        NaN     NaN
# 2    Flags,16-bit Service Class UUIDs (incomplete),...        NaN     NaN
# 3    Flags,16-bit Service Class UUIDs (incomplete),...        NaN     NaN
# 4    Flags,16-bit Service Class UUIDs (incomplete),...        NaN     NaN
# 5    Flags,16-bit Service Class UUIDs (incomplete),...        NaN     NaN
# ..                                                 ...        ...     ...
# 504                                              Flags        NaN     NaN
# 505                                                NaN        NaN     NaN
# 506                                              Flags        NaN     NaN
# 507                               Flags,Tx Power Level        NaN     NaN
# 508                                              Flags        NaN     NaN
#
#                                UUID Service Data                        PDU
# 0                            0x0c2c          NaN  ADV_IND[Malformed Packet]
# 2    Sennheiser Consumer Audio GmbH          NaN                    ADV_IND
# 3    Sennheiser Consumer Audio GmbH          NaN                    ADV_IND
# 4    Sennheiser Consumer Audio GmbH          NaN                    ADV_IND
# 5    Sennheiser Consumer Audio GmbH          NaN                    ADV_IND
# ..                              ...          ...                        ...
# 504                             NaN          NaN  ADV_IND[Malformed Packet]
# 505                             NaN          NaN                    ADV_IND
# 506                             NaN          NaN  ADV_IND[Malformed Packet]
# 507                             NaN          NaN  ADV_IND[Malformed Packet]
# 508                             NaN          NaN  ADV_IND[Malformed Packet]
#
# [508 rows x 15 columns]

# %%
synthetic_data = SmartTagData.groupby('UUID', dropna=False).sample(n = 50, random_state=0, replace=True)

# %%
synthetic_data = synthetic_data.reset_index(drop = True)
synthetic_data
# Out:
#      Number  Time Delta          Time             Source        Destination  \
# 0     97366  596.871986  1.714058e+09  6a:e6:d9:d3:35:62  ff:ff:ff:ff:ff:ff
# 1     97366  596.871986  1.714058e+09  6a:e6:d9:d3:35:62  ff:ff:ff:ff:ff:ff
# 2     97366  596.871986  1.714058e+09  6a:e6:d9:d3:35:62  ff:ff:ff:ff:ff:ff
# 3     97366  596.871986  1.714058e+09  6a:e6:d9:d3:35:62  ff:ff:ff:ff:ff:ff
# 4     97366  596.871986  1.714058e+09  6a:e6:d9:d3:35:62  ff:ff:ff:ff:ff:ff
# ..      ...         ...           ...                ...                ...
# 145   45325  277.332146  1.714058e+09  49:ef:e7:c0:1d:e3  ff:ff:ff:ff:ff:ff
# 146   60737  361.417866  1.714058e+09  80:c3:ba:47:3a:8b  ff:ff:ff:ff:ff:ff
# 147   71358  431.770407  1.714058e+09  69:ec:55:5c:2d:58  ff:ff:ff:ff:ff:ff
# 148   83163  530.914014  1.714058e+09  42:c9:eb:36:85:e3  ff:ff:ff:ff:ff:ff
# 149   71531  432.627877  1.714058e+09  69:ec:55:5c:2d:58  ff:ff:ff:ff:ff:ff
#
#     Protocol  Channel  Length Packet  Length Header  \
# 0      LE LL       37             51             25
# 1      LE LL       37             51             25
# 2      LE LL       37             51             25
# 3      LE LL       37             51             25
# 4      LE LL       37             51             25
# ..       ...      ...            ...            ...
# 145    LE LL       38             35              9
# 146    LE LL       39             32              6
# 147    LE LL       39             35              9
# 148    LE LL       37             42             16
# 149    LE LL       39             35              9
#
#                                                AD Type Company ID MS Data  \
# 0    Flags,16-bit Service Class UUIDs (incomplete),...        NaN     NaN
# 1    Flags,16-bit Service Class UUIDs (incomplete),...        NaN     NaN
# 2    Flags,16-bit Service Class UUIDs (incomplete),...        NaN     NaN
# 3    Flags,16-bit Service Class UUIDs (incomplete),...        NaN     NaN
# 4    Flags,16-bit Service Class UUIDs (incomplete),...        NaN     NaN
# ..                                                 ...        ...     ...
# 145                                              Flags        NaN     NaN
# 146                                                NaN        NaN     NaN
# 147                                              Flags        NaN     NaN
# 148                                         Flags,0x82        NaN     NaN
# 149                                              Flags        NaN     NaN
#
#        UUID Service Data                        PDU
# 0    0x0c2c          NaN  ADV_IND[Malformed Packet]
# 1    0x0c2c          NaN  ADV_IND[Malformed Packet]
# 2    0x0c2c          NaN  ADV_IND[Malformed Packet]
# 3    0x0c2c          NaN  ADV_IND[Malformed Packet]
# 4    0x0c2c          NaN  ADV_IND[Malformed Packet]
# ..      ...          ...                        ...
# 145     NaN          NaN                    ADV_IND
# 146     NaN          NaN                   SCAN_RSP
# 147     NaN          NaN                    ADV_IND
# 148     NaN          NaN  ADV_IND[Malformed Packet]
# 149     NaN          NaN                    ADV_IND
#
# [150 rows x 15 columns]

# %%
synthetic_data = pd.concat([synthetic_data] * 4000, ignore_index=True)
synthetic_data
# Out:
#         Number  Time Delta          Time             Source  \
# 0        97366  596.871986  1.714058e+09  6a:e6:d9:d3:35:62
# 1        97366  596.871986  1.714058e+09  6a:e6:d9:d3:35:62
# 2        97366  596.871986  1.714058e+09  6a:e6:d9:d3:35:62
# 3        97366  596.871986  1.714058e+09  6a:e6:d9:d3:35:62
# 4        97366  596.871986  1.714058e+09  6a:e6:d9:d3:35:62
# ...        ...         ...           ...                ...
# 599995   45325  277.332146  1.714058e+09  49:ef:e7:c0:1d:e3
# 599996   60737  361.417866  1.714058e+09  80:c3:ba:47:3a:8b
# 599997   71358  431.770407  1.714058e+09  69:ec:55:5c:2d:58
# 599998   83163  530.914014  1.714058e+09  42:c9:eb:36:85:e3
# 599999   71531  432.627877  1.714058e+09  69:ec:55:5c:2d:58
#
#               Destination Protocol  Channel  Length Packet  Length Header  \
# 0       ff:ff:ff:ff:ff:ff    LE LL       37             51             25
# 1       ff:ff:ff:ff:ff:ff    LE LL       37             51             25
# 2       ff:ff:ff:ff:ff:ff    LE LL       37             51             25
# 3       ff:ff:ff:ff:ff:ff    LE LL       37             51             25
# 4       ff:ff:ff:ff:ff:ff    LE LL       37             51             25
# ...                   ...      ...      ...            ...            ...
# 599995  ff:ff:ff:ff:ff:ff    LE LL       38             35              9
# 599996  ff:ff:ff:ff:ff:ff    LE LL       39             32              6
# 599997  ff:ff:ff:ff:ff:ff    LE LL       39             35              9
# 599998  ff:ff:ff:ff:ff:ff    LE LL       37             42             16
# 599999  ff:ff:ff:ff:ff:ff    LE LL       39             35              9
#
#                                                   AD Type Company ID MS Data  \
# 0       Flags,16-bit Service Class UUIDs (incomplete),...        NaN     NaN
# 1       Flags,16-bit Service Class UUIDs (incomplete),...        NaN     NaN
# 2       Flags,16-bit Service Class UUIDs (incomplete),...        NaN     NaN
# 3       Flags,16-bit Service Class UUIDs (incomplete),...        NaN     NaN
# 4       Flags,16-bit Service Class UUIDs (incomplete),...        NaN     NaN
# ...                                                   ...        ...     ...
# 599995                                              Flags        NaN     NaN
# 599996                                                NaN        NaN     NaN
# 599997                                              Flags        NaN     NaN
# 599998                                         Flags,0x82        NaN     NaN
# 599999                                              Flags        NaN     NaN
#
#           UUID Service Data                        PDU
# 0       0x0c2c          NaN  ADV_IND[Malformed Packet]
# 1       0x0c2c          NaN  ADV_IND[Malformed Packet]
# 2       0x0c2c          NaN  ADV_IND[Malformed Packet]
# 3       0x0c2c          NaN  ADV_IND[Malformed Packet]
# 4       0x0c2c          NaN  ADV_IND[Malformed Packet]
# ...        ...          ...                        ...
# 599995     NaN          NaN                    ADV_IND
# 599996     NaN          NaN                   SCAN_RSP
# 599997     NaN          NaN                    ADV_IND
# 599998     NaN          NaN  ADV_IND[Malformed Packet]
# 599999     NaN          NaN                    ADV_IND
#
# [600000 rows x 15 columns]

# %%
synthetic_data.to_csv(dataPath + r'\other Device\synthetic Data.csv', encoding='cp1252', index=False)
